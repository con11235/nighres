# %% [markdown]
# # tissues(func)
# ## sub001_sess1

# %%
import nighres
import os

skip_plots = False
try:
    from nilearn import plotting
except ImportError:
    skip_plots = True
    print('Nilearn could not be imported, plotting will be skipped')


in_dir = os.path.join(os.getcwd(), 'nighres_examples/tissue_classification')
out_dir = os.path.join(os.getcwd(), 'nighres_examples/cortical_depth_estimation')

segmentation = os.path.join(in_dir, 'sub001_sess1_mgdm-seg.nii.gz')
boundary_dist = os.path.join(in_dir, 'sub001_sess1_mgdm-dist.nii.gz')
max_labels = os.path.join(in_dir, 'sub001_sess1_mgdm-lbls.nii.gz')
max_probas = os.path.join(in_dir, 'sub001_sess1_mgdm-mems.nii.gz')

# %% [markdown]
# ### Region Extraction

# %%
cortex = nighres.brain.extract_brain_region(segmentation=segmentation,
                                            levelset_boundary=boundary_dist,
                                            maximum_membership=max_probas,
                                            maximum_label=max_labels,
                                            extracted_region='tissues(func)',
                                            save_data=True,
                                            file_name='sub001_sess1_tissues(func)',
                                            output_dir=out_dir)
# Out:
# Extract Brain Region
#
# Outputs will be saved to /home/cons/python/nighres_examples/cortical_depth_estimation/
# skip computation (use existing results)

# %%
if not skip_plots:
    plotting.plot_img(cortex['region_proba'],
        vmin=0, vmax=1, cmap='autumn', colorbar=True,
        annotate=False, draw_cross=False)
    plotting.plot_img(cortex['inside_proba'],
        vmin=0, vmax=1, cmap='autumn', colorbar=True,
        annotate=False, draw_cross=False)

# %% [markdown]
# ### CRUISE

# %%
cruise = nighres.cortex.cruise_cortex_extraction(
                        init_image=cortex['inside_mask'],
                        wm_image=cortex['inside_proba'],
                        gm_image=cortex['region_proba'],
                        csf_image=cortex['background_proba'],
                        normalize_probabilities=True,
                        save_data=True,
                        file_name="sub001_sess1_tissues(func)",
                        output_dir=out_dir)
# Out:
# CRUISE Cortical Extraction
#
# Outputs will be saved to /home/cons/python/nighres_examples/cortical_depth_estimation/
# skip computation (use existing results)

# %%
if not skip_plots:
    plotting.plot_img(cruise['cortex'],
                      vmin=0, vmax=2, cmap='cubehelix',  colorbar=True,
                      annotate=False,  draw_cross=False)

# %% [markdown]
# ### Volumetric layering

# %%
depth = nighres.laminar.volumetric_layering(
                        inner_levelset=cruise['gwb'],
                        outer_levelset=cruise['cgb'],
                        n_layers=4,
                        save_data=True,
                        file_name="sub001_sess1_tissues(func)",
                        output_dir=out_dir)
# Out:
# Volumetric Layering
#
# Outputs will be saved to /home/cons/python/nighres_examples/cortical_depth_estimation/
# skip computation (use existing results)

# %%
if not skip_plots:
    plotting.plot_img(depth['depth'],
                      vmin=0, vmax=1, cmap='autumn',  colorbar=True,
                      annotate=False,  draw_cross=False)

# %% [markdown]
# ## sub002_sess1

# %%
segmentation = os.path.join(in_dir, 'sub002_sess1_mgdm-seg.nii.gz')
boundary_dist = os.path.join(in_dir, 'sub002_sess1_mgdm-dist.nii.gz')
max_labels = os.path.join(in_dir, 'sub002_sess1_mgdm-lbls.nii.gz')
max_probas = os.path.join(in_dir, 'sub002_sess1_mgdm-mems.nii.gz')
cortex2 = nighres.brain.extract_brain_region(segmentation=segmentation,
                                            levelset_boundary=boundary_dist,
                                            maximum_membership=max_probas,
                                            maximum_label=max_labels,
                                            extracted_region='tissues(func)',
                                            save_data=True,
                                            file_name='sub002_sess1_tissues(func)',
                                            output_dir=out_dir)
# Out:
# Extract Brain Region
#
# Outputs will be saved to /home/cons/python/nighres_examples/cortical_depth_estimation/
# skip computation (use existing results)

# %%
if not skip_plots:
    plotting.plot_img(cortex2['region_proba'],
        vmin=0, vmax=1, cmap='autumn', colorbar=True,
        annotate=False, draw_cross=False)
    plotting.plot_img(cortex2['inside_proba'],
        vmin=0, vmax=1, cmap='autumn', colorbar=True,
        annotate=False, draw_cross=False)

# %%
cruise2 = nighres.cortex.cruise_cortex_extraction(
                        init_image=cortex2['inside_mask'],
                        wm_image=cortex2['inside_proba'],
                        gm_image=cortex2['region_proba'],
                        csf_image=cortex2['background_proba'],
                        normalize_probabilities=True,
                        save_data=True,
                        file_name="sub002_sess1_tissues(func)",
                        output_dir=out_dir)
# Out:
# CRUISE Cortical Extraction
#
# Outputs will be saved to /home/cons/python/nighres_examples/cortical_depth_estimation/
# Opening LUT: java.io.FileInputStream@439f5b3d
# Simple points: 25985144
# Opening LUT: java.io.FileInputStream@377dca04
# Simple points: 25985144
# fast marching init
# done
# GDM forces: 0.0 (edges), 0.4 (balloon), 0.1 (curvature), 0.0 (divergence)
# Opening LUT: java.io.FileInputStream@26a1ab54
# Simple points: 7985920
# initial GDM decomposition
# fast marching
# init
# done
# initialization
# level set segmentation...
# level set evolution: narrow band
# init (2825219)
# iteration 0
# changed labels: 0 (0.0 % of boundary)
# iteration 1
# changed labels: 63 (0.01207917 % of boundary)
# iteration 2
# changed labels: 657 (0.12596849 % of boundary)
# iteration 3
# changed labels: 1903 (0.36486766 % of boundary)
# iteration 4
# changed labels: 3307 (0.63406056 % of boundary)
# iteration 5
# changed labels: 3780 (0.7247502 % of boundary)
# iteration 6
# changed labels: 3909 (0.74948376 % of boundary)
# iteration 7
# changed labels: 3827 (0.73376167 % of boundary)
# iteration 8
# changed labels: 3638 (0.69752413 % of boundary)
# iteration 9
# changed labels: 3195 (0.6125865 % of boundary)
# iteration 10
# changed labels: 2867 (0.5496981 % of boundary)
# iteration 11
# changed labels: 2654 (0.50885904 % of boundary)
# iteration 12
# changed labels: 2529 (0.4848924 % of boundary)
# iteration 13
# changed labels: 2432 (0.46629432 % of boundary)
# iteration 14
# changed labels: 2328 (0.4463541 % of boundary)
# iteration 15
# changed labels: 2274 (0.43600053 % of boundary)
# iteration 16
# changed labels: 2284 (0.43791783 % of boundary)
# iteration 17
# changed labels: 2011 (0.3855748 % of boundary)
# iteration 18
# changed labels: 1948 (0.37349564 % of boundary)
# iteration 19
# changed labels: 1861 (0.35681486 % of boundary)
# iteration 20
# changed labels: 1802 (0.34550261 % of boundary)
# iteration 21
# changed labels: 1693 (0.32460374 % of boundary)
# iteration 22
# changed labels: 1674 (0.32096082 % of boundary)
# iteration 23
# changed labels: 1657 (0.31770134 % of boundary)
# iteration 24
# changed labels: 1578 (0.30255446 % of boundary)
# iteration 25
# changed labels: 1450 (0.27801263 % of boundary)
# iteration 26
# changed labels: 1444 (0.27686223 % of boundary)
# iteration 27
# changed labels: 1410 (0.27034333 % of boundary)
# iteration 28
# changed labels: 1431 (0.27436972 % of boundary)
# iteration 29
# changed labels: 1321 (0.25327912 % of boundary)
# iteration 30
# changed labels: 1350 (0.25883937 % of boundary)
# iteration 31
# changed labels: 1279 (0.24522634 % of boundary)
# iteration 32
# changed labels: 1153 (0.221068 % of boundary)
# iteration 33
# changed labels: 1180 (0.22624478 % of boundary)
# iteration 34
# changed labels: 1170 (0.22432746 % of boundary)
# iteration 35
# changed labels: 1176 (0.22547784 % of boundary)
# iteration 36
# changed labels: 1102 (0.21128961 % of boundary)
# iteration 37
# changed labels: 1067 (0.20457897 % of boundary)
# iteration 38
# changed labels: 1056 (0.2024699 % of boundary)
# iteration 39
# changed labels: 1053 (0.20189472 % of boundary)
# iteration 40
# changed labels: 1072 (0.20553763 % of boundary)
# iteration 41
# changed labels: 984 (0.18866514 % of boundary)
# iteration 42
# changed labels: 994 (0.19058247 % of boundary)
# iteration 43
# changed labels: 969 (0.18578914 % of boundary)
# iteration 44
# changed labels: 1015 (0.19460885 % of boundary)
# iteration 45
# changed labels: 981 (0.18808994 % of boundary)
# iteration 46
# changed labels: 919 (0.1762025 % of boundary)
# iteration 47
# changed labels: 958 (0.18368009 % of boundary)
# iteration 48
# changed labels: 887 (0.17006704 % of boundary)
# iteration 49
# changed labels: 878 (0.16834146 % of boundary)
# iteration 50
# changed labels: 836 (0.16028868 % of boundary)
# iteration 51
# changed labels: 849 (0.16278121 % of boundary)
# iteration 52
# changed labels: 827 (0.15856308 % of boundary)
# iteration 53
# changed labels: 843 (0.1616308 % of boundary)
# iteration 54
# changed labels: 795 (0.15242763 % of boundary)
# iteration 55
# changed labels: 829 (0.15894654 % of boundary)
# iteration 56
# changed labels: 769 (0.14744256 % of boundary)
# iteration 57
# changed labels: 771 (0.14782605 % of boundary)
# iteration 58
# changed labels: 826 (0.15837134 % of boundary)
# re-initialization
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# iteration 59
# changed labels: 2060 (0.31183064 % of boundary)
# iteration 60
# changed labels: 1312 (0.19860281 % of boundary)
# iteration 61
# changed labels: 1140 (0.17256647 % of boundary)
# iteration 62
# changed labels: 1014 (0.15349333 % of boundary)
# iteration 63
# changed labels: 1049 (0.15879142 % of boundary)
# iteration 64
# changed labels: 983 (0.14880073 % of boundary)
# iteration 65
# changed labels: 945 (0.14304852 % of boundary)
# iteration 66
# changed labels: 940 (0.14229165 % of boundary)
# iteration 67
# changed labels: 937 (0.14183752 % of boundary)
# iteration 68
# changed labels: 868 (0.13139272 % of boundary)
# iteration 69
# changed labels: 854 (0.12927347 % of boundary)
# iteration 70
# changed labels: 840 (0.12715425 % of boundary)
# iteration 71
# changed labels: 770 (0.11655806 % of boundary)
# iteration 72
# changed labels: 767 (0.11610393 % of boundary)
# iteration 73
# changed labels: 729 (0.11035171 % of boundary)
# iteration 74
# changed labels: 704 (0.10656737 % of boundary)
# iteration 75
# changed labels: 685 (0.10369126 % of boundary)
# iteration 76
# changed labels: 711 (0.10762699 % of boundary)
# iteration 77
# changed labels: 702 (0.10626461 % of boundary)
# iteration 78
# changed labels: 665 (0.100663766 % of boundary)
# iteration 79
# changed labels: 691 (0.104599506 % of boundary)
# iteration 80
# changed labels: 648 (0.09809042 % of boundary)
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# GDM forces: 0.0 (edges), 0.4 (balloon), 0.1 (curvature), 0.0 (divergence)
# Opening LUT: java.io.FileInputStream@5a10411
# Simple points: 7985920
# initial GDM decomposition
# fast marching
# init
# done
# initialization
# level set segmentation...
# level set evolution: narrow band
# init (3116250)
# iteration 0
# changed labels: 0 (0.0 % of boundary)
# iteration 1
# changed labels: 8898 (1.5348339 % of boundary)
# iteration 2
# changed labels: 83090 (14.332361 % of boundary)
# iteration 3
# changed labels: 63894 (11.021204 % of boundary)
# iteration 4
# changed labels: 53223 (9.180542 % of boundary)
# iteration 5
# changed labels: 32801 (5.6579103 % of boundary)
# iteration 6
# changed labels: 26092 (4.5006614 % of boundary)
# iteration 7
# changed labels: 30131 (5.1973567 % of boundary)
# iteration 8
# changed labels: 34604 (5.9689136 % of boundary)
# iteration 9
# changed labels: 31240 (5.3886504 % of boundary)
# iteration 10
# changed labels: 29483 (5.085582 % of boundary)
# iteration 11
# changed labels: 32785 (5.6551504 % of boundary)
# iteration 12
# changed labels: 33362 (5.7546782 % of boundary)
# iteration 13
# changed labels: 31702 (5.468342 % of boundary)
# iteration 14
# changed labels: 30965 (5.341215 % of boundary)
# iteration 15
# changed labels: 30172 (5.2044287 % of boundary)
# iteration 16
# changed labels: 29620 (5.1092134 % of boundary)
# iteration 17
# changed labels: 28750 (4.959145 % of boundary)
# iteration 18
# changed labels: 28406 (4.899808 % of boundary)
# iteration 19
# changed labels: 28233 (4.869967 % of boundary)
# iteration 20
# changed labels: 28226 (4.8687596 % of boundary)
# iteration 21
# changed labels: 27813 (4.79752 % of boundary)
# iteration 22
# changed labels: 27285 (4.7064447 % of boundary)
# iteration 23
# changed labels: 26402 (4.554134 % of boundary)
# iteration 24
# changed labels: 25655 (4.4252825 % of boundary)
# iteration 25
# changed labels: 25514 (4.400961 % of boundary)
# iteration 26
# changed labels: 24850 (4.2864265 % of boundary)
# iteration 27
# changed labels: 24375 (4.2044926 % of boundary)
# iteration 28
# changed labels: 24061 (4.15033 % of boundary)
# iteration 29
# changed labels: 23445 (4.0440755 % of boundary)
# iteration 30
# changed labels: 23216 (4.004575 % of boundary)
# iteration 31
# changed labels: 22887 (3.9478247 % of boundary)
# iteration 32
# changed labels: 21991 (3.7932715 % of boundary)
# iteration 33
# changed labels: 21562 (3.7192729 % of boundary)
# iteration 34
# changed labels: 21165 (3.6507936 % of boundary)
# iteration 35
# changed labels: 20708 (3.5719645 % of boundary)
# iteration 36
# changed labels: 20109 (3.4686418 % of boundary)
# iteration 37
# changed labels: 20017 (3.4527726 % of boundary)
# iteration 38
# changed labels: 19470 (3.3584192 % of boundary)
# iteration 39
# changed labels: 19227 (3.3165038 % of boundary)
# iteration 40
# changed labels: 18650 (3.216976 % of boundary)
# re-initialization
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# iteration 41
# changed labels: 18387 (2.368781 % of boundary)
# iteration 42
# changed labels: 18063 (2.3270404 % of boundary)
# iteration 43
# changed labels: 18686 (2.407301 % of boundary)
# iteration 44
# changed labels: 18613 (2.3978965 % of boundary)
# iteration 45
# changed labels: 18641 (2.4015038 % of boundary)
# iteration 46
# changed labels: 18325 (2.3607938 % of boundary)
# iteration 47
# changed labels: 18586 (2.394418 % of boundary)
# iteration 48
# changed labels: 18402 (2.3707135 % of boundary)
# iteration 49
# changed labels: 17968 (2.3148017 % of boundary)
# iteration 50
# changed labels: 17381 (2.2391791 % of boundary)
# iteration 51
# changed labels: 16677 (2.1484833 % of boundary)
# iteration 52
# changed labels: 16063 (2.0693822 % of boundary)
# iteration 53
# changed labels: 16151 (2.0807192 % of boundary)
# iteration 54
# changed labels: 15369 (1.9799749 % of boundary)
# iteration 55
# changed labels: 15376 (1.9808766 % of boundary)
# iteration 56
# changed labels: 14742 (1.899199 % of boundary)
# iteration 57
# changed labels: 14386 (1.8533359 % of boundary)
# iteration 58
# changed labels: 14114 (1.8182943 % of boundary)
# iteration 59
# changed labels: 13917 (1.792915 % of boundary)
# iteration 60
# changed labels: 13482 (1.7368743 % of boundary)
# iteration 61
# changed labels: 13200 (1.7005444 % of boundary)
# iteration 62
# changed labels: 12928 (1.665503 % of boundary)
# iteration 63
# changed labels: 12439 (1.6025056 % of boundary)
# iteration 64
# changed labels: 12367 (1.5932298 % of boundary)
# iteration 65
# changed labels: 12118 (1.5611514 % of boundary)
# iteration 66
# changed labels: 11641 (1.4996998 % of boundary)
# iteration 67
# changed labels: 11354 (1.4627259 % of boundary)
# iteration 68
# changed labels: 11330 (1.459634 % of boundary)
# iteration 69
# changed labels: 10983 (1.4149302 % of boundary)
# iteration 70
# changed labels: 10642 (1.3709995 % of boundary)
# iteration 71
# changed labels: 10333 (1.3311913 % of boundary)
# iteration 72
# changed labels: 10300 (1.32694 % of boundary)
# iteration 73
# changed labels: 10141 (1.3064561 % of boundary)
# iteration 74
# changed labels: 10008 (1.2893219 % of boundary)
# iteration 75
# changed labels: 9765 (1.2580163 % of boundary)
# iteration 76
# changed labels: 9742 (1.2550533 % of boundary)
# iteration 77
# changed labels: 9384 (1.2089325 % of boundary)
# iteration 78
# changed labels: 9226 (1.1885775 % of boundary)
# iteration 79
# changed labels: 9053 (1.16629 % of boundary)
# iteration 80
# changed labels: 8877 (1.1436162 % of boundary)
# iteration 81
# changed labels: 8516 (1.0971088 % of boundary)
# iteration 82
# changed labels: 8523 (1.0980105 % of boundary)
# re-initialization
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# iteration 83
# changed labels: 9103 (1.0267035 % of boundary)
# iteration 84
# changed labels: 8263 (0.93196213 % of boundary)
# iteration 85
# changed labels: 8276 (0.9334284 % of boundary)
# iteration 86
# changed labels: 8107 (0.9143673 % of boundary)
# iteration 87
# changed labels: 8148 (0.91899157 % of boundary)
# iteration 88
# changed labels: 7921 (0.89338887 % of boundary)
# iteration 89
# changed labels: 7846 (0.8849298 % of boundary)
# iteration 90
# changed labels: 7969 (0.89880264 % of boundary)
# iteration 91
# changed labels: 7827 (0.88278687 % of boundary)
# iteration 92
# changed labels: 7835 (0.88368917 % of boundary)
# iteration 93
# changed labels: 7654 (0.86327463 % of boundary)
# iteration 94
# changed labels: 7478 (0.8434241 % of boundary)
# iteration 95
# changed labels: 7455 (0.84082997 % of boundary)
# iteration 96
# changed labels: 7268 (0.8197387 % of boundary)
# iteration 97
# changed labels: 7155 (0.8069937 % of boundary)
# iteration 98
# changed labels: 7198 (0.8118436 % of boundary)
# iteration 99
# changed labels: 6970 (0.7861281 % of boundary)
# iteration 100
# changed labels: 6938 (0.78251886 % of boundary)
# iteration 101
# changed labels: 7013 (0.79097795 % of boundary)
# iteration 102
# changed labels: 6595 (0.74383277 % of boundary)
# iteration 103
# changed labels: 6664 (0.7516151 % of boundary)
# iteration 104
# changed labels: 6577 (0.74180263 % of boundary)
# iteration 105
# changed labels: 6540 (0.7376295 % of boundary)
# iteration 106
# changed labels: 6612 (0.7457502 % of boundary)
# iteration 107
# changed labels: 6535 (0.73706555 % of boundary)
# iteration 108
# changed labels: 6279 (0.708192 % of boundary)
# iteration 109
# changed labels: 6332 (0.71416974 % of boundary)
# iteration 110
# changed labels: 6059 (0.68337876 % of boundary)
# iteration 111
# changed labels: 6170 (0.6958982 % of boundary)
# iteration 112
# changed labels: 6195 (0.69871783 % of boundary)
# iteration 113
# changed labels: 6073 (0.68495774 % of boundary)
# iteration 114
# changed labels: 5975 (0.6739046 % of boundary)
# iteration 115
# changed labels: 6009 (0.6777394 % of boundary)
# iteration 116
# changed labels: 5794 (0.6534901 % of boundary)
# iteration 117
# changed labels: 5747 (0.6481891 % of boundary)
# iteration 118
# changed labels: 5715 (0.6445799 % of boundary)
# iteration 119
# changed labels: 5731 (0.6463845 % of boundary)
# iteration 120
# changed labels: 5645 (0.6366848 % of boundary)
# iteration 121
# changed labels: 5622 (0.63409066 % of boundary)
# iteration 122
# changed labels: 5511 (0.62157124 % of boundary)
# iteration 123
# changed labels: 5358 (0.6043148 % of boundary)
# iteration 124
# changed labels: 5386 (0.60747284 % of boundary)
# iteration 125
# changed labels: 5390 (0.607924 % of boundary)
# iteration 126
# changed labels: 5263 (0.5936 % of boundary)
# iteration 127
# changed labels: 5332 (0.6013823 % of boundary)
# re-initialization
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# iteration 128
# changed labels: 6617 (0.6828908 % of boundary)
# iteration 129
# changed labels: 5382 (0.5554357 % of boundary)
# iteration 130
# changed labels: 5139 (0.53035754 % of boundary)
# iteration 131
# changed labels: 5148 (0.5312863 % of boundary)
# iteration 132
# changed labels: 5091 (0.5254038 % of boundary)
# iteration 133
# changed labels: 4922 (0.5079626 % of boundary)
# iteration 134
# changed labels: 4816 (0.4970231 % of boundary)
# iteration 135
# changed labels: 4742 (0.4893861 % of boundary)
# iteration 136
# changed labels: 4723 (0.48742527 % of boundary)
# iteration 137
# changed labels: 4760 (0.49124378 % of boundary)
# iteration 138
# changed labels: 4711 (0.48618683 % of boundary)
# iteration 139
# changed labels: 4677 (0.482678 % of boundary)
# iteration 140
# changed labels: 4749 (0.49010855 % of boundary)
# iteration 141
# changed labels: 4616 (0.4763826 % of boundary)
# iteration 142
# changed labels: 4645 (0.4793755 % of boundary)
# iteration 143
# changed labels: 4469 (0.46121186 % of boundary)
# iteration 144
# changed labels: 4459 (0.46017984 % of boundary)
# iteration 145
# changed labels: 4496 (0.46399832 % of boundary)
# iteration 146
# changed labels: 4393 (0.45336848 % of boundary)
# iteration 147
# changed labels: 4448 (0.4590446 % of boundary)
# iteration 148
# changed labels: 4402 (0.4542973 % of boundary)
# iteration 149
# changed labels: 4329 (0.44676355 % of boundary)
# iteration 150
# changed labels: 4406 (0.4547101 % of boundary)
# iteration 151
# changed labels: 4313 (0.44511226 % of boundary)
# iteration 152
# changed labels: 4282 (0.44191298 % of boundary)
# iteration 153
# changed labels: 4276 (0.44129378 % of boundary)
# iteration 154
# changed labels: 4321 (0.44593787 % of boundary)
# iteration 155
# changed labels: 4120 (0.4251942 % of boundary)
# iteration 156
# changed labels: 4150 (0.4282903 % of boundary)
# iteration 157
# changed labels: 4046 (0.4175572 % of boundary)
# iteration 158
# changed labels: 4221 (0.43561766 % of boundary)
# iteration 159
# changed labels: 4123 (0.42550382 % of boundary)
# iteration 160
# changed labels: 3982 (0.41095227 % of boundary)
# iteration 161
# changed labels: 4065 (0.41951808 % of boundary)
# iteration 162
# changed labels: 3882 (0.40063202 % of boundary)
# iteration 163
# changed labels: 3821 (0.39433664 % of boundary)
# iteration 164
# changed labels: 3804 (0.3925822 % of boundary)
# iteration 165
# changed labels: 3841 (0.3964007 % of boundary)
# iteration 166
# changed labels: 3768 (0.38886693 % of boundary)
# iteration 167
# changed labels: 3687 (0.38050753 % of boundary)
# iteration 168
# changed labels: 3701 (0.38195238 % of boundary)
# re-initialization
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# iteration 169
# changed labels: 6022 (0.58416396 % of boundary)
# iteration 170
# changed labels: 4399 (0.42672488 % of boundary)
# iteration 171
# changed labels: 4075 (0.39529526 % of boundary)
# iteration 172
# changed labels: 3921 (0.3803565 % of boundary)
# iteration 173
# changed labels: 3697 (0.35862738 % of boundary)
# iteration 174
# changed labels: 3628 (0.35193405 % of boundary)
# iteration 175
# changed labels: 3562 (0.3455317 % of boundary)
# iteration 176
# changed labels: 3435 (0.33321208 % of boundary)
# iteration 177
# changed labels: 3435 (0.33321208 % of boundary)
# iteration 178
# changed labels: 3325 (0.32254153 % of boundary)
# iteration 179
# changed labels: 3263 (0.31652722 % of boundary)
# iteration 180
# changed labels: 3213 (0.31167698 % of boundary)
# iteration 181
# changed labels: 3278 (0.31798232 % of boundary)
# iteration 182
# changed labels: 3133 (0.30391657 % of boundary)
# iteration 183
# changed labels: 3165 (0.30702072 % of boundary)
# iteration 184
# changed labels: 3077 (0.2984843 % of boundary)
# iteration 185
# changed labels: 3063 (0.29712623 % of boundary)
# iteration 186
# changed labels: 2994 (0.29043287 % of boundary)
# iteration 187
# changed labels: 3083 (0.29906633 % of boundary)
# iteration 188
# changed labels: 2997 (0.2907239 % of boundary)
# iteration 189
# changed labels: 2966 (0.28771675 % of boundary)
# iteration 190
# changed labels: 2977 (0.28878382 % of boundary)
# iteration 191
# changed labels: 2849 (0.27636716 % of boundary)
# iteration 192
# changed labels: 2834 (0.2749121 % of boundary)
# iteration 193
# changed labels: 2789 (0.27054685 % of boundary)
# iteration 194
# changed labels: 2718 (0.2636595 % of boundary)
# iteration 195
# changed labels: 2719 (0.2637565 % of boundary)
# iteration 196
# changed labels: 2721 (0.26395053 % of boundary)
# iteration 197
# changed labels: 2676 (0.25958532 % of boundary)
# iteration 198
# changed labels: 2723 (0.26414454 % of boundary)
# iteration 199
# changed labels: 2591 (0.25133988 % of boundary)
# iteration 200
# changed labels: 2597 (0.25192192 % of boundary)
# iteration 201
# changed labels: 2609 (0.25308597 % of boundary)
# iteration 202
# changed labels: 2616 (0.25376502 % of boundary)
# iteration 203
# changed labels: 2628 (0.25492907 % of boundary)
# iteration 204
# changed labels: 2476 (0.24018432 % of boundary)
# iteration 205
# changed labels: 2447 (0.23737116 % of boundary)
# iteration 206
# changed labels: 2432 (0.2359161 % of boundary)
# iteration 207
# changed labels: 2402 (0.23300594 % of boundary)
# re-initialization
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# iteration 208
# changed labels: 5015 (0.4676457 % of boundary)
# iteration 209
# changed labels: 3434 (0.32021844 % of boundary)
# iteration 210
# changed labels: 2949 (0.27499247 % of boundary)
# iteration 211
# changed labels: 2729 (0.25447762 % of boundary)
# iteration 212
# changed labels: 2688 (0.2506544 % of boundary)
# iteration 213
# changed labels: 2429 (0.22650278 % of boundary)
# iteration 214
# changed labels: 2439 (0.22743528 % of boundary)
# iteration 215
# changed labels: 2308 (0.21521962 % of boundary)
# iteration 216
# changed labels: 2312 (0.21559261 % of boundary)
# iteration 217
# changed labels: 2324 (0.2167116 % of boundary)
# iteration 218
# changed labels: 2299 (0.21438035 % of boundary)
# iteration 219
# changed labels: 2115 (0.19722249 % of boundary)
# iteration 220
# changed labels: 2160 (0.2014187 % of boundary)
# iteration 221
# changed labels: 2068 (0.19283976 % of boundary)
# iteration 222
# changed labels: 2170 (0.20235118 % of boundary)
# iteration 223
# changed labels: 2169 (0.20225793 % of boundary)
# iteration 224
# changed labels: 1974 (0.18407431 % of boundary)
# iteration 225
# changed labels: 2090 (0.19489124 % of boundary)
# iteration 226
# changed labels: 2014 (0.18780428 % of boundary)
# iteration 227
# changed labels: 2013 (0.18771103 % of boundary)
# iteration 228
# changed labels: 1996 (0.1861258 % of boundary)
# iteration 229
# changed labels: 1982 (0.1848203 % of boundary)
# iteration 230
# changed labels: 1994 (0.1859393 % of boundary)
# iteration 231
# changed labels: 1913 (0.17838609 % of boundary)
# iteration 232
# changed labels: 1993 (0.18584605 % of boundary)
# iteration 233
# changed labels: 1958 (0.18258232 % of boundary)
# iteration 234
# changed labels: 1975 (0.18416756 % of boundary)
# iteration 235
# changed labels: 2030 (0.18929628 % of boundary)
# iteration 236
# changed labels: 1908 (0.17791985 % of boundary)
# iteration 237
# changed labels: 1928 (0.17978483 % of boundary)
# iteration 238
# changed labels: 1844 (0.17195189 % of boundary)
# iteration 239
# changed labels: 1825 (0.17018014 % of boundary)
# iteration 240
# changed labels: 1817 (0.16943416 % of boundary)
# iteration 241
# changed labels: 1823 (0.16999364 % of boundary)
# iteration 242
# changed labels: 1878 (0.17512237 % of boundary)
# iteration 243
# changed labels: 1764 (0.16449194 % of boundary)
# iteration 244
# changed labels: 1716 (0.16001597 % of boundary)
# iteration 245
# changed labels: 1768 (0.16486493 % of boundary)
# iteration 246
# changed labels: 1879 (0.17521562 % of boundary)
# iteration 247
# changed labels: 1755 (0.16365269 % of boundary)
# iteration 248
# changed labels: 1714 (0.15982947 % of boundary)
# iteration 249
# changed labels: 1686 (0.15721849 % of boundary)
# iteration 250
# changed labels: 1657 (0.15451425 % of boundary)
# iteration 251
# changed labels: 1722 (0.16057546 % of boundary)
# iteration 252
# changed labels: 1726 (0.16094846 % of boundary)
# iteration 253
# changed labels: 1764 (0.16449194 % of boundary)
# iteration 254
# changed labels: 1731 (0.16141471 % of boundary)
# iteration 255
# changed labels: 1543 (0.14388382 % of boundary)
# re-initialization
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# iteration 256
# changed labels: 4315 (0.38749942 % of boundary)
# iteration 257
# changed labels: 2856 (0.25647703 % of boundary)
# iteration 258
# changed labels: 2355 (0.21148577 % of boundary)
# iteration 259
# changed labels: 2102 (0.18876566 % of boundary)
# iteration 260
# changed labels: 2013 (0.1807732 % of boundary)
# iteration 261
# changed labels: 1764 (0.1584123 % of boundary)
# iteration 262
# changed labels: 1722 (0.15464056 % of boundary)
# iteration 263
# changed labels: 1592 (0.14296618 % of boundary)
# iteration 264
# changed labels: 1603 (0.14395402 % of boundary)
# iteration 265
# changed labels: 1554 (0.13955368 % of boundary)
# iteration 266
# changed labels: 1551 (0.13928427 % of boundary)
# iteration 267
# changed labels: 1465 (0.13156122 % of boundary)
# iteration 268
# changed labels: 1501 (0.13479412 % of boundary)
# iteration 269
# changed labels: 1468 (0.13183063 % of boundary)
# iteration 270
# changed labels: 1349 (0.121144086 % of boundary)
# iteration 271
# changed labels: 1343 (0.120605275 % of boundary)
# iteration 272
# changed labels: 1404 (0.12608324 % of boundary)
# iteration 273
# changed labels: 1334 (0.11979705 % of boundary)
# iteration 274
# changed labels: 1381 (0.124017775 % of boundary)
# iteration 275
# changed labels: 1427 (0.12814872 % of boundary)
# iteration 276
# changed labels: 1425 (0.12796912 % of boundary)
# iteration 277
# changed labels: 1319 (0.11845001 % of boundary)
# iteration 278
# changed labels: 1303 (0.117013164 % of boundary)
# iteration 279
# changed labels: 1352 (0.1214135 % of boundary)
# iteration 280
# changed labels: 1324 (0.11889902 % of boundary)
# iteration 281
# changed labels: 1356 (0.12177271 % of boundary)
# iteration 282
# changed labels: 1376 (0.123568766 % of boundary)
# iteration 283
# changed labels: 1352 (0.1214135 % of boundary)
# iteration 284
# changed labels: 1317 (0.1182704 % of boundary)
# iteration 285
# changed labels: 1325 (0.11898882 % of boundary)
# iteration 286
# changed labels: 1251 (0.11234341 % of boundary)
# iteration 287
# changed labels: 1300 (0.11674375 % of boundary)
# iteration 288
# changed labels: 1268 (0.113870054 % of boundary)
# iteration 289
# changed labels: 1226 (0.11009833 % of boundary)
# iteration 290
# changed labels: 1214 (0.1090207 % of boundary)
# iteration 291
# changed labels: 1268 (0.113870054 % of boundary)
# iteration 292
# changed labels: 1278 (0.11476808 % of boundary)
# iteration 293
# changed labels: 1257 (0.11288222 % of boundary)
# iteration 294
# changed labels: 1184 (0.10632662 % of boundary)
# iteration 295
# changed labels: 1291 (0.11593552 % of boundary)
# iteration 296
# changed labels: 1244 (0.11171479 % of boundary)
# iteration 297
# changed labels: 1201 (0.10785326 % of boundary)
# iteration 298
# changed labels: 1222 (0.109739125 % of boundary)
# iteration 299
# changed labels: 1191 (0.10695524 % of boundary)
# iteration 300
# changed labels: 1197 (0.107494056 % of boundary)
# iteration 301
# changed labels: 1220 (0.10955952 % of boundary)
# iteration 302
# changed labels: 1206 (0.10830228 % of boundary)
# re-initialization
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# iteration 303
# changed labels: 3975 (0.34781465 % of boundary)
# iteration 304
# changed labels: 2501 (0.21883887 % of boundary)
# iteration 305
# changed labels: 1963 (0.17176358 % of boundary)
# iteration 306
# changed labels: 1728 (0.15120094 % of boundary)
# iteration 307
# changed labels: 1692 (0.14805093 % of boundary)
# iteration 308
# changed labels: 1503 (0.13151331 % of boundary)
# iteration 309
# changed labels: 1328 (0.11620072 % of boundary)
# iteration 310
# changed labels: 1322 (0.115675725 % of boundary)
# iteration 311
# changed labels: 1200 (0.10500066 % of boundary)
# iteration 312
# changed labels: 1181 (0.103338145 % of boundary)
# iteration 313
# changed labels: 1117 (0.09773812 % of boundary)
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# Opening LUT: java.io.FileInputStream@2ef1e4fa
# Simple points: 7985920
# average estimation...
#
# Saving /home/cons/python/nighres_examples/cortical_depth_estimation/sub002_sess1_tissues(func)_cruise-cortex.nii.gz
#
# Saving /home/cons/python/nighres_examples/cortical_depth_estimation/sub002_sess1_tissues(func)_cruise-gwb.nii.gz
#
# Saving /home/cons/python/nighres_examples/cortical_depth_estimation/sub002_sess1_tissues(func)_cruise-cgb.nii.gz
#
# Saving /home/cons/python/nighres_examples/cortical_depth_estimation/sub002_sess1_tissues(func)_cruise-avg.nii.gz
#
# Saving /home/cons/python/nighres_examples/cortical_depth_estimation/sub002_sess1_tissues(func)_cruise-thick.nii.gz
#
# Saving /home/cons/python/nighres_examples/cortical_depth_estimation/sub002_sess1_tissues(func)_cruise-pwm.nii.gz
#
# Saving /home/cons/python/nighres_examples/cortical_depth_estimation/sub002_sess1_tissues(func)_cruise-pgm.nii.gz
#
# Saving /home/cons/python/nighres_examples/cortical_depth_estimation/sub002_sess1_tissues(func)_cruise-pcsf.nii.gz

# %%
if not skip_plots:
    plotting.plot_img(cruise2['cortex'],
                      vmin=0, vmax=2, cmap='cubehelix',  colorbar=True,
                      annotate=False,  draw_cross=False)

# %%
depth2 = nighres.laminar.volumetric_layering(
                        inner_levelset=cruise2['gwb'],
                        outer_levelset=cruise2['cgb'],
                        n_layers=4,
                        save_data=True,
                        file_name="sub002_sess1_tissues(func)",
                        output_dir=out_dir)
# Out:
# Volumetric Layering
#
# Outputs will be saved to /home/cons/python/nighres_examples/cortical_depth_estimation/
# initialize levelset functions and computation area...
# inner curvature (3)...
# outer curvature (3)...
# distance-preserving evolution
# GDM forces: 0.9 (balloon), 0.1 (smoothing)
# initial GDM decomposition
# initialization
# 1-th layer estimation...
# level set evolution: narrow band
# init (3069097)
# iteration 0
# changed labels: 84603 (12.645054 % of boundary)
# critical points (0)
# iteration 1
# changed labels: 95019 (14.201864 % of boundary)
# critical points (0)
# iteration 2
# changed labels: 70371 (10.517891 % of boundary)
# critical points (0)
# iteration 3
# changed labels: 54672 (8.171465 % of boundary)
# critical points (0)
# iteration 4
# changed labels: 40654 (6.076286 % of boundary)
# critical points (0)
# iteration 5
# changed labels: 30087 (4.496906 % of boundary)
# critical points (0)
# iteration 6
# changed labels: 22370 (3.3434968 % of boundary)
# critical points (0)
# iteration 7
# changed labels: 16936 (2.5313127 % of boundary)
# critical points (0)
# iteration 8
# changed labels: 12273 (1.8343647 % of boundary)
# critical points (0)
# iteration 9
# changed labels: 9234 (1.3801453 % of boundary)
# critical points (0)
# iteration 10
# changed labels: 6634 (0.99154043 % of boundary)
# critical points (0)
# iteration 11
# changed labels: 5025 (0.75105375 % of boundary)
# critical points (0)
# iteration 12
# changed labels: 3719 (0.5558545 % of boundary)
# critical points (0)
# iteration 13
# changed labels: 2771 (0.41416314 % of boundary)
# critical points (0)
# re-initialization
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# iteration 14
# changed labels: 2561 (0.3927655 % of boundary)
# critical points (0)
# iteration 15
# changed labels: 1667 (0.255658 % of boundary)
# critical points (0)
# iteration 16
# changed labels: 1258 (0.19293207 % of boundary)
# critical points (0)
# iteration 17
# changed labels: 985 (0.15106365 % of boundary)
# critical points (0)
# iteration 18
# changed labels: 666 (0.1021405 % of boundary)
# critical points (0)
# iteration 19
# changed labels: 509 (0.07806233 % of boundary)
# critical points (0)
# iteration 20
# changed labels: 381 (0.05843173 % of boundary)
# critical points (0)
# iteration 21
# changed labels: 314 (0.048156332 % of boundary)
# critical points (0)
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# 2-th layer estimation...
# level set evolution: narrow band
# init (3285680)
# iteration 0
# changed labels: 110088 (16.846628 % of boundary)
# critical points (0)
# iteration 1
# changed labels: 97976 (14.993145 % of boundary)
# critical points (0)
# iteration 2
# changed labels: 77775 (11.901811 % of boundary)
# critical points (0)
# iteration 3
# changed labels: 57556 (8.807722 % of boundary)
# critical points (0)
# iteration 4
# changed labels: 43122 (6.5989056 % of boundary)
# critical points (0)
# iteration 5
# changed labels: 31834 (4.871517 % of boundary)
# critical points (0)
# iteration 6
# changed labels: 23726 (3.63076 % of boundary)
# critical points (0)
# iteration 7
# changed labels: 17520 (2.6810637 % of boundary)
# critical points (0)
# iteration 8
# changed labels: 12864 (1.9685619 % of boundary)
# critical points (0)
# iteration 9
# changed labels: 9535 (1.4591291 % of boundary)
# critical points (0)
# iteration 10
# changed labels: 7080 (1.0834435 % of boundary)
# critical points (0)
# iteration 11
# changed labels: 5028 (0.76942855 % of boundary)
# critical points (0)
# iteration 12
# changed labels: 3624 (0.5545762 % of boundary)
# critical points (0)
# iteration 13
# changed labels: 2683 (0.4105761 % of boundary)
# critical points (0)
# re-initialization
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# iteration 14
# changed labels: 2221 (0.3296876 % of boundary)
# critical points (0)
# iteration 15
# changed labels: 1496 (0.22206783 % of boundary)
# critical points (0)
# iteration 16
# changed labels: 1128 (0.16744153 % of boundary)
# critical points (0)
# iteration 17
# changed labels: 864 (0.12825309 % of boundary)
# critical points (0)
# iteration 18
# changed labels: 680 (0.10093993 % of boundary)
# critical points (0)
# iteration 19
# changed labels: 568 (0.08431453 % of boundary)
# critical points (0)
# iteration 20
# changed labels: 388 (0.057595138 % of boundary)
# critical points (0)
# iteration 21
# changed labels: 358 (0.053141907 % of boundary)
# critical points (0)
# iteration 22
# changed labels: 258 (0.0382978 % of boundary)
# critical points (0)
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# 3-th layer estimation...
# level set evolution: narrow band
# init (3519088)
# iteration 0
# changed labels: 116042 (17.159172 % of boundary)
# critical points (0)
# iteration 1
# changed labels: 102186 (15.110281 % of boundary)
# critical points (0)
# iteration 2
# changed labels: 83546 (12.353978 % of boundary)
# critical points (0)
# iteration 3
# changed labels: 64179 (9.490172 % of boundary)
# critical points (0)
# iteration 4
# changed labels: 50528 (7.4715943 % of boundary)
# critical points (0)
# iteration 5
# changed labels: 39553 (5.8487167 % of boundary)
# critical points (0)
# iteration 6
# changed labels: 31227 (4.617548 % of boundary)
# critical points (0)
# iteration 7
# changed labels: 24084 (3.56131 % of boundary)
# critical points (0)
# iteration 8
# changed labels: 19050 (2.8169305 % of boundary)
# critical points (0)
# iteration 9
# changed labels: 15069 (2.2282586 % of boundary)
# critical points (0)
# iteration 10
# changed labels: 12117 (1.7917452 % of boundary)
# critical points (0)
# iteration 11
# changed labels: 9569 (1.4149716 % of boundary)
# critical points (0)
# iteration 12
# changed labels: 7634 (1.1288424 % of boundary)
# critical points (0)
# iteration 13
# changed labels: 5967 (0.88234246 % of boundary)
# critical points (0)
# re-initialization
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# iteration 14
# changed labels: 5181 (0.68262666 % of boundary)
# critical points (0)
# iteration 15
# changed labels: 3996 (0.52649605 % of boundary)
# critical points (0)
# iteration 16
# changed labels: 3269 (0.43070963 % of boundary)
# critical points (0)
# iteration 17
# changed labels: 2760 (0.36364594 % of boundary)
# critical points (0)
# iteration 18
# changed labels: 2278 (0.30013967 % of boundary)
# critical points (0)
# iteration 19
# changed labels: 1787 (0.23544757 % of boundary)
# critical points (0)
# iteration 20
# changed labels: 1525 (0.20092756 % of boundary)
# critical points (0)
# iteration 21
# changed labels: 1235 (0.16271839 % of boundary)
# critical points (0)
# iteration 22
# changed labels: 1008 (0.13280982 % of boundary)
# critical points (0)
# iteration 23
# changed labels: 886 (0.116735615 % of boundary)
# critical points (0)
# iteration 24
# changed labels: 662 (0.08722232 % of boundary)
# critical points (0)
# iteration 25
# changed labels: 580 (0.076418355 % of boundary)
# critical points (0)
# iteration 26
# changed labels: 478 (0.062979266 % of boundary)
# critical points (0)
# iteration 27
# changed labels: 423 (0.055732694 % of boundary)
# critical points (0)
# re-initialization
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# iteration 28
# changed labels: 932 (0.119826384 % of boundary)
# critical points (0)
# iteration 29
# changed labels: 338 (0.04345635 % of boundary)
# critical points (0)
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# volume-preserving modeling
# volume-preserving evolution
# GDM forces: 0.9 (balloon), 0.1 (smoothing)
# initial GDM decomposition
# initialization
# 1-th layer estimation...
# level set evolution: narrow band
# init (3069097)
# iteration 0
# changed labels: 83238 (12.441037 % of boundary)
# critical points (0)
# iteration 1
# changed labels: 89810 (13.42331 % of boundary)
# critical points (0)
# iteration 2
# changed labels: 67295 (10.058142 % of boundary)
# critical points (0)
# iteration 3
# changed labels: 54383 (8.12827 % of boundary)
# critical points (0)
# iteration 4
# changed labels: 42585 (6.3648996 % of boundary)
# critical points (0)
# iteration 5
# changed labels: 33137 (4.9527698 % of boundary)
# critical points (0)
# iteration 6
# changed labels: 26727 (3.9947088 % of boundary)
# critical points (0)
# iteration 7
# changed labels: 21351 (3.1911936 % of boundary)
# critical points (0)
# iteration 8
# changed labels: 16895 (2.5251846 % of boundary)
# critical points (0)
# iteration 9
# changed labels: 13445 (2.0095358 % of boundary)
# critical points (0)
# iteration 10
# changed labels: 10675 (1.595522 % of boundary)
# critical points (0)
# iteration 11
# changed labels: 8539 (1.2762681 % of boundary)
# critical points (0)
# iteration 12
# changed labels: 6788 (1.0145577 % of boundary)
# critical points (0)
# iteration 13
# changed labels: 5280 (0.78916687 % of boundary)
# critical points (0)
# re-initialization
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# iteration 14
# changed labels: 4637 (0.6409858 % of boundary)
# critical points (0)
# iteration 15
# changed labels: 3685 (0.5093881 % of boundary)
# critical points (0)
# iteration 16
# changed labels: 3016 (0.41691032 % of boundary)
# critical points (0)
# iteration 17
# changed labels: 2362 (0.326506 % of boundary)
# critical points (0)
# iteration 18
# changed labels: 1908 (0.2637483 % of boundary)
# critical points (0)
# iteration 19
# changed labels: 1497 (0.20693459 % of boundary)
# critical points (0)
# iteration 20
# changed labels: 1212 (0.16753823 % of boundary)
# critical points (0)
# iteration 21
# changed labels: 905 (0.12510073 % of boundary)
# critical points (0)
# iteration 22
# changed labels: 723 (0.09994236 % of boundary)
# critical points (0)
# iteration 23
# changed labels: 556 (0.07685747 % of boundary)
# critical points (0)
# iteration 24
# changed labels: 430 (0.05944013 % of boundary)
# critical points (0)
# iteration 25
# changed labels: 340 (0.046999175 % of boundary)
# critical points (0)
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# 2-th layer estimation...
# level set evolution: narrow band
# init (3478979)
# iteration 0
# changed labels: 123449 (16.776358 % of boundary)
# critical points (0)
# iteration 1
# changed labels: 102428 (13.919666 % of boundary)
# critical points (0)
# iteration 2
# changed labels: 78242 (10.632859 % of boundary)
# critical points (0)
# iteration 3
# changed labels: 57173 (7.7696433 % of boundary)
# critical points (0)
# iteration 4
# changed labels: 41732 (5.671257 % of boundary)
# critical points (0)
# iteration 5
# changed labels: 30002 (4.077184 % of boundary)
# critical points (0)
# iteration 6
# changed labels: 21611 (2.9368718 % of boundary)
# critical points (0)
# iteration 7
# changed labels: 15988 (2.1727226 % of boundary)
# critical points (0)
# iteration 8
# changed labels: 11637 (1.5814344 % of boundary)
# critical points (0)
# iteration 9
# changed labels: 8792 (1.1948072 % of boundary)
# critical points (0)
# iteration 10
# changed labels: 6479 (0.8804772 % of boundary)
# critical points (0)
# iteration 11
# changed labels: 4721 (0.6415701 % of boundary)
# critical points (0)
# iteration 12
# changed labels: 3731 (0.507032 % of boundary)
# critical points (0)
# iteration 13
# changed labels: 2775 (0.3771144 % of boundary)
# critical points (0)
# iteration 14
# changed labels: 2159 (0.29340178 % of boundary)
# critical points (0)
# re-initialization
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# iteration 15
# changed labels: 1853 (0.23326455 % of boundary)
# critical points (0)
# iteration 16
# changed labels: 1306 (0.16440557 % of boundary)
# critical points (0)
# iteration 17
# changed labels: 1155 (0.14539696 % of boundary)
# critical points (0)
# iteration 18
# changed labels: 982 (0.12361888 % of boundary)
# critical points (0)
# iteration 19
# changed labels: 779 (0.09806427 % of boundary)
# critical points (0)
# iteration 20
# changed labels: 636 (0.08006274 % of boundary)
# critical points (0)
# iteration 21
# changed labels: 558 (0.07024372 % of boundary)
# critical points (0)
# iteration 22
# changed labels: 417 (0.052493967 % of boundary)
# critical points (0)
# iteration 23
# changed labels: 337 (0.04242318 % of boundary)
# critical points (0)
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# 3-th layer estimation...
# level set evolution: narrow band
# init (3796632)
# iteration 0
# changed labels: 138302 (17.266815 % of boundary)
# critical points (0)
# iteration 1
# changed labels: 114723 (14.323008 % of boundary)
# critical points (0)
# iteration 2
# changed labels: 86566 (10.807646 % of boundary)
# critical points (0)
# iteration 3
# changed labels: 61765 (7.711275 % of boundary)
# critical points (0)
# iteration 4
# changed labels: 44196 (5.51781 % of boundary)
# critical points (0)
# iteration 5
# changed labels: 31988 (3.9936576 % of boundary)
# critical points (0)
# iteration 6
# changed labels: 23425 (2.924579 % of boundary)
# critical points (0)
# iteration 7
# changed labels: 16865 (2.105572 % of boundary)
# critical points (0)
# iteration 8
# changed labels: 12573 (1.5697217 % of boundary)
# critical points (0)
# iteration 9
# changed labels: 9429 (1.1771976 % of boundary)
# critical points (0)
# iteration 10
# changed labels: 7232 (0.9029052 % of boundary)
# critical points (0)
# iteration 11
# changed labels: 5433 (0.6783026 % of boundary)
# critical points (0)
# iteration 12
# changed labels: 4306 (0.5375982 % of boundary)
# critical points (0)
# iteration 13
# changed labels: 3411 (0.42585865 % of boundary)
# critical points (0)
# iteration 14
# changed labels: 2801 (0.349701 % of boundary)
# critical points (0)
# re-initialization
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# iteration 15
# changed labels: 2423 (0.28398937 % of boundary)
# critical points (0)
# iteration 16
# changed labels: 1715 (0.20100772 % of boundary)
# critical points (0)
# iteration 17
# changed labels: 1681 (0.19702274 % of boundary)
# critical points (0)
# iteration 18
# changed labels: 1362 (0.15963413 % of boundary)
# critical points (0)
# iteration 19
# changed labels: 1139 (0.13349727 % of boundary)
# critical points (0)
# iteration 20
# changed labels: 1017 (0.11919817 % of boundary)
# critical points (0)
# iteration 21
# changed labels: 870 (0.10196894 % of boundary)
# critical points (0)
# iteration 22
# changed labels: 669 (0.078410596 % of boundary)
# critical points (0)
# iteration 23
# changed labels: 620 (0.072667524 % of boundary)
# critical points (0)
# iteration 24
# changed labels: 521 (0.061064154 % of boundary)
# critical points (0)
# iteration 25
# changed labels: 423 (0.049578004 % of boundary)
# critical points (0)
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# generate outputs
# ...layering
# ...labels
# ...surfaces
# done
#
# Saving /home/cons/python/nighres_examples/cortical_depth_estimation/sub002_sess1_tissues(func)_layering-depth.nii.gz
#
# Saving /home/cons/python/nighres_examples/cortical_depth_estimation/sub002_sess1_tissues(func)_layering-layers.nii.gz
#
# Saving /home/cons/python/nighres_examples/cortical_depth_estimation/sub002_sess1_tissues(func)_layering-boundaries.nii.gz

# %%
if not skip_plots:
    plotting.plot_img(depth2['depth'],
                      vmin=0, vmax=1, cmap='autumn',  colorbar=True,
                      annotate=False,  draw_cross=False)
