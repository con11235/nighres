# %% [markdown]
# # cerebellum
# ## sub001_sess1

# %%
import nighres
import os

skip_plots = False
try:
    from nilearn import plotting
except ImportError:
    skip_plots = True
    print('Nilearn could not be imported, plotting will be skipped')


in_dir = os.path.join(os.getcwd(), 'nighres_examples/tissue_classification')
out_dir = os.path.join(os.getcwd(), 'nighres_examples/cortical_depth_estimation')

segmentation = os.path.join(in_dir, 'sub001_sess1_mgdm-seg.nii.gz')
boundary_dist = os.path.join(in_dir, 'sub001_sess1_mgdm-dist.nii.gz')
max_labels = os.path.join(in_dir, 'sub001_sess1_mgdm-lbls.nii.gz')
max_probas = os.path.join(in_dir, 'sub001_sess1_mgdm-mems.nii.gz')

# %% [markdown]
# ### Region Extraction

# %%
cortex = nighres.brain.extract_brain_region(segmentation=segmentation,
                                            levelset_boundary=boundary_dist,
                                            maximum_membership=max_probas,
                                            maximum_label=max_labels,
                                            extracted_region='cerebellum',
                                            save_data=True,
                                            file_name='sub001_sess1_cerebellum',
                                            output_dir=out_dir)
# Out:
# Extract Brain Region
#
# Outputs will be saved to /home/cons/python/nighres_examples/cortical_depth_estimation/
# skip computation (use existing results)

# %%
if not skip_plots:
    plotting.plot_img(cortex['region_proba'],
        vmin=0, vmax=1, cmap='autumn', colorbar=True,
        annotate=False, draw_cross=False)
    plotting.plot_img(cortex['inside_proba'],
        vmin=0, vmax=1, cmap='autumn', colorbar=True,
        annotate=False, draw_cross=False)

# %% [markdown]
# ### CRUISE

# %%
cruise = nighres.cortex.cruise_cortex_extraction(
                        init_image=cortex['inside_mask'],
                        wm_image=cortex['inside_proba'],
                        gm_image=cortex['region_proba'],
                        csf_image=cortex['background_proba'],
                        normalize_probabilities=True,
                        save_data=True,
                        file_name="sub001_sess1_cerebellum",
                        output_dir=out_dir)
# Out:
# CRUISE Cortical Extraction
#
# Outputs will be saved to /home/cons/python/nighres_examples/cortical_depth_estimation/
# skip computation (use existing results)

# %%
if not skip_plots:
    plotting.plot_img(cruise['cortex'],
                      vmin=0, vmax=2, cmap='cubehelix',  colorbar=True,
                      annotate=False,  draw_cross=False)

# %% [markdown]
# ### Volumetric layering

# %%
depth = nighres.laminar.volumetric_layering(
                        inner_levelset=cruise['gwb'],
                        outer_levelset=cruise['cgb'],
                        n_layers=4,
                        save_data=True,
                        file_name="sub001_sess1_cerebellum",
                        output_dir=out_dir)
# Out:
# Volumetric Layering
#
# Outputs will be saved to /home/cons/python/nighres_examples/cortical_depth_estimation/
# skip computation (use existing results)

# %%
if not skip_plots:
    plotting.plot_img(depth['depth'],
                      vmin=0, vmax=1, cmap='autumn',  colorbar=True,
                      annotate=False,  draw_cross=False)

# %% [markdown]
# ## sub002_sess1

# %%
segmentation = os.path.join(in_dir, 'sub002_sess1_mgdm-seg.nii.gz')
boundary_dist = os.path.join(in_dir, 'sub002_sess1_mgdm-dist.nii.gz')
max_labels = os.path.join(in_dir, 'sub002_sess1_mgdm-lbls.nii.gz')
max_probas = os.path.join(in_dir, 'sub002_sess1_mgdm-mems.nii.gz')
cortex2 = nighres.brain.extract_brain_region(segmentation=segmentation,
                                            levelset_boundary=boundary_dist,
                                            maximum_membership=max_probas,
                                            maximum_label=max_labels,
                                            extracted_region='cerebellum',
                                            save_data=True,
                                            file_name='sub002_sess1_cerebellum',
                                            output_dir=out_dir)
# Out:
# Extract Brain Region
#
# Outputs will be saved to /home/cons/python/nighres_examples/cortical_depth_estimation/
# skip computation (use existing results)

# %%
if not skip_plots:
    plotting.plot_img(cortex2['region_proba'],
        vmin=0, vmax=1, cmap='autumn', colorbar=True,
        annotate=False, draw_cross=False)
    plotting.plot_img(cortex2['inside_proba'],
        vmin=0, vmax=1, cmap='autumn', colorbar=True,
        annotate=False, draw_cross=False)

# %%
cruise2 = nighres.cortex.cruise_cortex_extraction(
                        init_image=cortex2['inside_mask'],
                        wm_image=cortex2['inside_proba'],
                        gm_image=cortex2['region_proba'],
                        csf_image=cortex2['background_proba'],
                        normalize_probabilities=True,
                        save_data=True,
                        file_name="sub002_sess1_cerebellum",
                        output_dir=out_dir)
# Out:
# CRUISE Cortical Extraction
#
# Outputs will be saved to /home/cons/python/nighres_examples/cortical_depth_estimation/
# skip computation (use existing results)

# %%
if not skip_plots:
    plotting.plot_img(cruise2['cortex'],
                      vmin=0, vmax=2, cmap='cubehelix',  colorbar=True,
                      annotate=False,  draw_cross=False)

# %%
depth2 = nighres.laminar.volumetric_layering(
                        inner_levelset=cruise2['gwb'],
                        outer_levelset=cruise2['cgb'],
                        n_layers=4,
                        save_data=True,
                        file_name="sub002_sess1_cerebellum",
                        output_dir=out_dir)
# Out:
# Volumetric Layering
#
# Outputs will be saved to /home/cons/python/nighres_examples/cortical_depth_estimation/
# initialize levelset functions and computation area...
# inner curvature (3)...
# outer curvature (3)...
# distance-preserving evolution
# GDM forces: 0.9 (balloon), 0.1 (smoothing)
# initial GDM decomposition
# initialization
# 1-th layer estimation...
# level set evolution: narrow band
# init (413199)
# iteration 0
# changed labels: 13722 (12.673754 % of boundary)
# critical points (0)
# iteration 1
# changed labels: 13139 (12.13529 % of boundary)
# critical points (0)
# iteration 2
# changed labels: 10860 (10.030387 % of boundary)
# critical points (0)
# iteration 3
# changed labels: 8997 (8.309704 % of boundary)
# critical points (0)
# iteration 4
# changed labels: 7070 (6.529911 % of boundary)
# critical points (0)
# iteration 5
# changed labels: 5253 (4.8517146 % of boundary)
# critical points (0)
# iteration 6
# changed labels: 3906 (3.6076143 % of boundary)
# critical points (0)
# iteration 7
# changed labels: 2922 (2.6987836 % of boundary)
# critical points (0)
# iteration 8
# changed labels: 2083 (1.9238763 % of boundary)
# critical points (0)
# iteration 9
# changed labels: 1568 (1.4482179 % of boundary)
# critical points (0)
# iteration 10
# changed labels: 1046 (0.9660943 % of boundary)
# critical points (0)
# iteration 11
# changed labels: 821 (0.7582825 % of boundary)
# critical points (0)
# iteration 12
# changed labels: 641 (0.59203297 % of boundary)
# critical points (0)
# iteration 13
# changed labels: 437 (0.40361685 % of boundary)
# critical points (0)
# iteration 14
# changed labels: 354 (0.32695737 % of boundary)
# critical points (0)
# iteration 15
# changed labels: 272 (0.25122148 % of boundary)
# critical points (0)
# iteration 16
# changed labels: 220 (0.20319384 % of boundary)
# critical points (0)
# iteration 17
# changed labels: 157 (0.14500651 % of boundary)
# critical points (0)
# iteration 18
# changed labels: 137 (0.12653434 % of boundary)
# critical points (0)
# iteration 19
# changed labels: 94 (0.08681918 % of boundary)
# critical points (0)
# iteration 20
# changed labels: 66 (0.060958154 % of boundary)
# critical points (0)
# iteration 21
# changed labels: 67 (0.06188176 % of boundary)
# critical points (0)
# iteration 22
# changed labels: 48 (0.0443332 % of boundary)
# critical points (0)
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# 2-th layer estimation...
# level set evolution: narrow band
# init (426062)
# iteration 0
# changed labels: 12749 (14.271802 % of boundary)
# critical points (0)
# iteration 1
# changed labels: 10675 (11.950072 % of boundary)
# critical points (0)
# iteration 2
# changed labels: 8517 (9.534311 % of boundary)
# critical points (0)
# iteration 3
# changed labels: 5963 (6.675249 % of boundary)
# critical points (0)
# iteration 4
# changed labels: 4261 (4.769954 % of boundary)
# critical points (0)
# iteration 5
# changed labels: 2817 (3.1534758 % of boundary)
# critical points (0)
# iteration 6
# changed labels: 1945 (2.17732 % of boundary)
# critical points (0)
# iteration 7
# changed labels: 1296 (1.4508004 % of boundary)
# critical points (0)
# iteration 8
# changed labels: 972 (1.0881003 % of boundary)
# critical points (0)
# iteration 9
# changed labels: 666 (0.7455502 % of boundary)
# critical points (0)
# iteration 10
# changed labels: 452 (0.5059891 % of boundary)
# critical points (0)
# iteration 11
# changed labels: 314 (0.35150567 % of boundary)
# critical points (0)
# iteration 12
# changed labels: 257 (0.28769732 % of boundary)
# critical points (0)
# iteration 13
# changed labels: 180 (0.20150007 % of boundary)
# critical points (0)
# iteration 14
# changed labels: 134 (0.1500056 % of boundary)
# critical points (0)
# iteration 15
# changed labels: 97 (0.10858615 % of boundary)
# critical points (0)
# iteration 16
# changed labels: 78 (0.08731669 % of boundary)
# critical points (0)
# iteration 17
# changed labels: 58 (0.064927794 % of boundary)
# critical points (0)
# iteration 18
# changed labels: 45 (0.05037502 % of boundary)
# critical points (0)
# iteration 19
# changed labels: 33 (0.036941677 % of boundary)
# critical points (0)
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# 3-th layer estimation...
# level set evolution: narrow band
# init (444795)
# iteration 0
# changed labels: 11796 (14.219416 % of boundary)
# critical points (0)
# iteration 1
# changed labels: 9321 (11.235941 % of boundary)
# critical points (0)
# iteration 2
# changed labels: 7455 (8.986584 % of boundary)
# critical points (0)
# iteration 3
# changed labels: 5546 (6.685391 % of boundary)
# critical points (0)
# iteration 4
# changed labels: 4022 (4.848295 % of boundary)
# critical points (0)
# iteration 5
# changed labels: 2919 (3.5186906 % of boundary)
# critical points (0)
# iteration 6
# changed labels: 2042 (2.4615164 % of boundary)
# critical points (0)
# iteration 7
# changed labels: 1523 (1.8358909 % of boundary)
# critical points (0)
# iteration 8
# changed labels: 1150 (1.3862604 % of boundary)
# critical points (0)
# iteration 9
# changed labels: 781 (0.94145167 % of boundary)
# critical points (0)
# iteration 10
# changed labels: 615 (0.74134797 % of boundary)
# critical points (0)
# iteration 11
# changed labels: 451 (0.54365516 % of boundary)
# critical points (0)
# iteration 12
# changed labels: 338 (0.40743998 % of boundary)
# critical points (0)
# iteration 13
# changed labels: 272 (0.3278807 % of boundary)
# critical points (0)
# iteration 14
# changed labels: 194 (0.2338561 % of boundary)
# critical points (0)
# iteration 15
# changed labels: 139 (0.16755669 % of boundary)
# critical points (0)
# iteration 16
# changed labels: 118 (0.14224236 % of boundary)
# critical points (0)
# iteration 17
# changed labels: 76 (0.09161373 % of boundary)
# critical points (0)
# iteration 18
# changed labels: 62 (0.07473751 % of boundary)
# critical points (0)
# iteration 19
# changed labels: 50 (0.060272187 % of boundary)
# critical points (0)
# iteration 20
# changed labels: 56 (0.06750485 % of boundary)
# critical points (0)
# iteration 21
# changed labels: 45 (0.05424497 % of boundary)
# critical points (0)
# iteration 22
# changed labels: 27 (0.032546982 % of boundary)
# critical points (0)
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# volume-preserving modeling
# volume-preserving evolution
# GDM forces: 0.9 (balloon), 0.1 (smoothing)
# initial GDM decomposition
# initialization
# 1-th layer estimation...
# level set evolution: narrow band
# init (413199)
# iteration 0
# changed labels: 13565 (12.528748 % of boundary)
# critical points (0)
# iteration 1
# changed labels: 12543 (11.58482 % of boundary)
# critical points (0)
# iteration 2
# changed labels: 10164 (9.387555 % of boundary)
# critical points (0)
# iteration 3
# changed labels: 8423 (7.779553 % of boundary)
# critical points (0)
# iteration 4
# changed labels: 6787 (6.2685294 % of boundary)
# critical points (0)
# iteration 5
# changed labels: 5272 (4.869263 % of boundary)
# critical points (0)
# iteration 6
# changed labels: 4070 (3.7590861 % of boundary)
# critical points (0)
# iteration 7
# changed labels: 3272 (3.0220466 % of boundary)
# critical points (0)
# iteration 8
# changed labels: 2433 (2.247139 % of boundary)
# critical points (0)
# iteration 9
# changed labels: 1877 (1.7336128 % of boundary)
# critical points (0)
# iteration 10
# changed labels: 1405 (1.2976698 % of boundary)
# critical points (0)
# iteration 11
# changed labels: 1109 (1.0242817 % of boundary)
# critical points (0)
# iteration 12
# changed labels: 791 (0.73057425 % of boundary)
# critical points (0)
# iteration 13
# changed labels: 583 (0.53846365 % of boundary)
# critical points (0)
# iteration 14
# changed labels: 469 (0.43317235 % of boundary)
# critical points (0)
# iteration 15
# changed labels: 403 (0.37221417 % of boundary)
# critical points (0)
# iteration 16
# changed labels: 326 (0.30109632 % of boundary)
# critical points (0)
# iteration 17
# changed labels: 222 (0.20504105 % of boundary)
# critical points (0)
# iteration 18
# changed labels: 199 (0.18379806 % of boundary)
# critical points (0)
# iteration 19
# changed labels: 165 (0.15239537 % of boundary)
# critical points (0)
# iteration 20
# changed labels: 119 (0.10990939 % of boundary)
# critical points (0)
# iteration 21
# changed labels: 102 (0.094208054 % of boundary)
# critical points (0)
# iteration 22
# changed labels: 66 (0.060958154 % of boundary)
# critical points (0)
# iteration 23
# changed labels: 59 (0.054492895 % of boundary)
# critical points (0)
# iteration 24
# changed labels: 67 (0.06188176 % of boundary)
# critical points (0)
# iteration 25
# changed labels: 50 (0.04618042 % of boundary)
# critical points (0)
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# 2-th layer estimation...
# level set evolution: narrow band
# init (442618)
# iteration 0
# changed labels: 14162 (14.400911 % of boundary)
# critical points (0)
# iteration 1
# changed labels: 11382 (11.574013 % of boundary)
# critical points (0)
# iteration 2
# changed labels: 8422 (8.564078 % of boundary)
# critical points (0)
# iteration 3
# changed labels: 5628 (5.722944 % of boundary)
# critical points (0)
# iteration 4
# changed labels: 4033 (4.101036 % of boundary)
# critical points (0)
# iteration 5
# changed labels: 2769 (2.8157127 % of boundary)
# critical points (0)
# iteration 6
# changed labels: 2035 (2.0693302 % of boundary)
# critical points (0)
# iteration 7
# changed labels: 1382 (1.4053142 % of boundary)
# critical points (0)
# iteration 8
# changed labels: 1017 (1.0341567 % of boundary)
# critical points (0)
# iteration 9
# changed labels: 742 (0.75451744 % of boundary)
# critical points (0)
# iteration 10
# changed labels: 534 (0.5430085 % of boundary)
# critical points (0)
# iteration 11
# changed labels: 403 (0.40979856 % of boundary)
# critical points (0)
# iteration 12
# changed labels: 333 (0.33861765 % of boundary)
# critical points (0)
# iteration 13
# changed labels: 225 (0.2287957 % of boundary)
# critical points (0)
# iteration 14
# changed labels: 150 (0.15253049 % of boundary)
# critical points (0)
# iteration 15
# changed labels: 124 (0.12609187 % of boundary)
# critical points (0)
# iteration 16
# changed labels: 102 (0.10372073 % of boundary)
# critical points (0)
# iteration 17
# changed labels: 72 (0.073214635 % of boundary)
# critical points (0)
# iteration 18
# changed labels: 49 (0.049826626 % of boundary)
# critical points (0)
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# 3-th layer estimation...
# level set evolution: narrow band
# init (471070)
# iteration 0
# changed labels: 13223 (14.09446 % of boundary)
# critical points (0)
# iteration 1
# changed labels: 10297 (10.975622 % of boundary)
# critical points (0)
# iteration 2
# changed labels: 7579 (8.078493 % of boundary)
# critical points (0)
# iteration 3
# changed labels: 5165 (5.5053988 % of boundary)
# critical points (0)
# iteration 4
# changed labels: 3656 (3.8969483 % of boundary)
# critical points (0)
# iteration 5
# changed labels: 2519 (2.6850145 % of boundary)
# critical points (0)
# iteration 6
# changed labels: 1749 (1.8642677 % of boundary)
# critical points (0)
# iteration 7
# changed labels: 1379 (1.4698828 % of boundary)
# critical points (0)
# iteration 8
# changed labels: 938 (0.99981886 % of boundary)
# critical points (0)
# iteration 9
# changed labels: 722 (0.76958334 % of boundary)
# critical points (0)
# iteration 10
# changed labels: 536 (0.57132506 % of boundary)
# critical points (0)
# iteration 11
# changed labels: 411 (0.43808693 % of boundary)
# critical points (0)
# iteration 12
# changed labels: 311 (0.33149642 % of boundary)
# critical points (0)
# iteration 13
# changed labels: 225 (0.2398286 % of boundary)
# critical points (0)
# iteration 14
# changed labels: 162 (0.1726766 % of boundary)
# critical points (0)
# iteration 15
# changed labels: 141 (0.15029259 % of boundary)
# critical points (0)
# iteration 16
# changed labels: 95 (0.10126097 % of boundary)
# critical points (0)
# iteration 17
# changed labels: 93 (0.09912916 % of boundary)
# critical points (0)
# iteration 18
# changed labels: 69 (0.07354744 % of boundary)
# critical points (0)
# iteration 19
# changed labels: 64 (0.06821791 % of boundary)
# critical points (0)
# iteration 20
# changed labels: 45 (0.04796572 % of boundary)
# critical points (0)
# level set evolution: iso-surface reinit
# fast marching
# init
# done
# generate outputs
# ...layering
# ...labels
# ...surfaces
# done
#
# Saving /home/cons/python/nighres_examples/cortical_depth_estimation/sub002_sess1_cerebellum_layering-depth.nii.gz
#
# Saving /home/cons/python/nighres_examples/cortical_depth_estimation/sub002_sess1_cerebellum_layering-layers.nii.gz
#
# Saving /home/cons/python/nighres_examples/cortical_depth_estimation/sub002_sess1_cerebellum_layering-boundaries.nii.gz

# %%
if not skip_plots:
    plotting.plot_img(depth2['depth'],
                      vmin=0, vmax=1, cmap='autumn',  colorbar=True,
                      annotate=False,  draw_cross=False)
